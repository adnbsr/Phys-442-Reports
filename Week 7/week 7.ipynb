# %%
from pylab import *

d=[[]]*15



d[0]=[7.05,12.15,17.25,22.80,28.20]
d[1]=[6.45,11.70,16.95,22.35,27.75]
d[2]=[6.15,11.25,16.65,21.90,27.15]
d[3]=[7.05,11.85,16.95,22.05,27.45]
d[4]=[6.45,11.40,16.65,21.75,26.85]
d[5]=[6.00,10.95,15.90,21.00,26.40]
d[6]=[7.05,11.85,16.95,22.20,27.45]
d[7]=[6.60,11.25,16.50,21.60,27.15]
d[8]=[6.00,11.10,16.05,21.15,26.40]
d[9]=[6.75,11.55,16.65,21.45,26.70]
d[10]=[6.45,11.25,16.05,21.15,26.25]
d[11]=[6.00,10.95,15.90,20.85,25.80]
d[12]=[7.05,11.70,16.65,21.45,26.40]
d[13]=[6.60,11.40,16.20,21.15,25.95]
d[14]=[6.30,11.10,15.60,20.85,25.65]

data=[]



for i in range(15):
    temp=[]
    for j in range(4):
        
        temp.append(d[i][j+1]-d[i][j])
    data.append(temp)
        
data=array(data)

print data

sigmas=[]  
means=[]


for i in data:
    print '---------'
    print i.mean()
    means.append(i.mean())
    print i.std()**2*(1.33)
    sigmas.append(i.std()**2*(1.33))
   

    
sigmas[11]=sigmas[10]  
means[11]=means[10] 


    
sigmas=array(sigmas)
means=array(means)

print len(sigmas)

sw=1.0/sum(1.0/sigmas) 
    
print "sw  :"+ str(sw)

vw=sum(means/sigmas)/sum(1.0/sigmas)

print "vw   :"+ str(vw)

print "stotal 2 :" + str((0.05)**2 + sw)

print "stotal 2 :" + str(sqrt((0.05)**2 + sw))

print 'error :'+ str(abs(4.9-vw)/(((0.05)**2 + sw)**(1.0/2)))
# Out:
# [[ 5.1   5.1   5.55  5.4 ]
#  [ 5.25  5.25  5.4   5.4 ]
#  [ 5.1   5.4   5.25  5.25]
#  [ 4.8   5.1   5.1   5.4 ]
#  [ 4.95  5.25  5.1   5.1 ]
#  [ 4.95  4.95  5.1   5.4 ]
#  [ 4.8   5.1   5.25  5.25]
#  [ 4.65  5.25  5.1   5.55]
#  [ 5.1   4.95  5.1   5.25]
#  [ 4.8   5.1   4.8   5.25]
#  [ 4.8   4.8   5.1   5.1 ]
#  [ 4.95  4.95  4.95  4.95]
#  [ 4.65  4.95  4.8   4.95]
#  [ 4.8   4.8   4.95  4.8 ]
#  [ 4.8   4.5   5.25  4.8 ]]
# ---------
# 5.2875
# 0.0504984375
# ---------
# 5.325
# 0.00748125
# ---------
# 5.25
# 0.0149625
# ---------
# 5.1
# 0.05985
# ---------
# 5.1
# 0.0149625
# ---------
# 5.1
# 0.0448875
# ---------
# 5.1
# 0.0448875
# ---------
# 5.1375
# 0.1402734375
# ---------
# 5.1
# 0.0149625
# ---------
# 4.9875
# 0.0504984375
# ---------
# 4.95
# 0.029925
# ---------
# 4.95
# 1.04918500394e-30
# ---------
# 4.8375
# 0.0205734375
# ---------
# 4.8375
# 0.0056109375
# ---------
# 4.8375
# 0.0953859375
# 15
# sw  :0.00133991800579
# vw   :5.05917664184
# ...

# %%
print
